# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.46.0-cp311-cp311-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\users\pvste\anaconda3\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\pvste\anaconda3\lib\site-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in c:\users\pvste\anaconda3\lib\site-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in c:\users\pvste\anaconda3\lib\site-packages (from shap) (2.1.4)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\pvste\anaconda3\lib\site-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in c:\users\pvste\anaconda3\lib\site-packages (from shap) (23.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\users\pvste\anaconda3\lib\site-packages (from shap) (0.59.0)
# Requirement already satisfied: cloudpickle in c:\users\pvste\anaconda3\lib\site-packages (from shap) (2.2.1)
# Requirement already satisfied: colorama in c:\users\pvste\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\pvste\anaconda3\lib\site-packages (from numba->shap) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pvste\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pvste\anaconda3\lib\site-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pvste\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\pvste\anaconda3\lib\site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pvste\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\pvste\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.46.0-cp311-cp311-win_amd64.whl (456 kB)
#    ---------------------------------------- 0.0/456.1 kB ? eta -:--:--
#     --------------------------------------- 10.2/456.1 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/456.1 kB 495.5 kB/s eta 0:00:01
#    ---- ---------------------------------- 51.2/456.1 kB 440.4 kB/s eta 0:00:01
#    ---- ---------------------------------- 51.2/456.1 kB 440.4 kB/s eta 0:00:01
#    ------- ------------------------------- 81.9/456.1 kB 459.5 kB/s eta 0:00:01
#    ----------- -------------------------- 133.1/456.1 kB 563.7 kB/s eta 0:00:01
#    ----------- -------------------------- 133.1/456.1 kB 563.7 kB/s eta 0:00:01
#    -------------------- ----------------- 245.8/456.1 kB 795.7 kB/s eta 0:00:01
#    ---------------------- --------------- 266.2/456.1 kB 864.9 kB/s eta 0:00:01
#    ---------------------- --------------- 266.2/456.1 kB 864.9 kB/s eta 0:00:01
#    ------------------------------------- -- 430.1/456.1 kB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  450.6/456.1 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------- 456.1/456.1 kB 984.2 kB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.46.0 slicer-0.0.8

# %%
import joblib
import pandas as pd
import shap

# Load the model
model = joblib.load('model.pkl')
print(type(model))

# Load your dataset (replace 'your_dataset.csv' with your actual dataset file)
df = pd.read_csv('dataset_part1.csv')

# Prepare the data for SHAP
X = df.drop('Label', axis=1)  # Drop the target column if it's in the dataset

# Initialize the SHAP explainer for the Random Forest model
explainer = shap.TreeExplainer(model)

# Compute SHAP values
shap_values = explainer.shap_values(X)

# Visualize SHAP values
shap.summary_plot(shap_values, X)
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
